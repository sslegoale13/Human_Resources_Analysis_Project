# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
employees = pd.read_excel("Human Resources Data.xlsx")

# %%
employees.head()
# Out:
#   Employee Number  Age  Gender Marital Status          Education  \
# 0         STAFF-1   41  Female         Single  Associates Degree
# 1         STAFF-2   49    Male        Married        High School
# 2         STAFF-4   37    Male         Single  Associates Degree
# 3         STAFF-5   33  Female        Married    Master's Degree
# 4         STAFF-7   27    Male        Married        High School
#
#   Education Field               Job Role Department    Business Travel  \
# 0   Life Sciences        Sales Executive      Sales      Travel Rarely
# 1   Life Sciences     Research Scientist        R&D  Travel Frequently
# 2           Other  Laboratory Technician        R&D      Travel Rarely
# 3   Life Sciences     Research Scientist        R&D  Travel Frequently
# 4         Medical  Laboratory Technician        R&D      Travel Rarely
#
#   Attrition  ... Performance Rating  Relationship Satisfaction  \
# 0       Yes  ...                  3                          1
# 1        No  ...                  4                          4
# 2       Yes  ...                  3                          2
# 3        No  ...                  3                          3
# 4        No  ...                  3                          4
#
#    Standard Hours  Stock Option Level  Total Working Years  Work Life Balance  \
# 0              80                   0                    8                  1
# 1              80                   1                   10                  3
# 2              80                   0                    7                  3
# 3              80                   0                    8                  3
# 4              80                   1                    6                  3
#
#    Years At Company  Years In Current Role  Years Since Last Promotion  \
# 0                 6                      4                           0
# 1                10                      7                           1
# 2                 0                      0                           0
# 3                 8                      7                           3
# 4                 2                      2                           2
#
#    Years With Current Manager
# 0                           5
# 1                           7
# 2                           0
# 3                           0
# 4                           2
#
# [5 rows x 33 columns]
